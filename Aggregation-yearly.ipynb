# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
print(" Start aggregation of the 5 rotations for the rainfed and irrigated system")
# Out:
#  Start aggregation of the 5 rotations for the rainfed and irrigated system

# %%
fract = np.array([[2009,0.08,0.46,0.10,0.30,0.07],[2010,0.08,0.46,0.10,0.30,0.07],[2011,0.08,0.42,0.10,0.33,0.07],[2012,0.10,0.41,0.10,0.31,0.08],[2013,0.11,0.40,0.13,0.31,0.09],[2014,0.10,0.34,0.12,0.29,0.13],[2015,0.09,0.34,0.13,0.28,0.13],[2016,0.10,0.35,0.14,0.25,0.09]])
fract = np.array([[2009,0.08,0.45,0.09,0.09,0.29],[2010,0.08,0.45,0.09,0.09,0.29],[2011,0.42,0.10,0.10,0.32,0.07],[2012,0.15,0.15,0.45,0.11,0.14],[2013,0.13,0.29,0.09,0.10,0.39],[2014,0.29,0.13,0.10,0.35,0.12],[2015,0.15,0.11,0.43,0.16,0.16],[2016,0.10,0.36,0.14,0.14,0.25]])
dfract= pd.DataFrame(fract,columns=['year','rot1', 'rot2', 'rot3', 'rot4', 'rot5'])
dfract = dfract.set_index("year")
print ("Land use fractions of the crops within the 5 rotations... [%/100]")
dfract.head(n=10)
# Out:
# Land use fractions of the crops within the 5 rotations... [%/100]
#         rot1  rot2  rot3  rot4  rot5
# year
# 2009.0  0.08  0.45  0.09  0.09  0.29
# 2010.0  0.08  0.45  0.09  0.09  0.29
# 2011.0  0.42  0.10  0.10  0.32  0.07
# 2012.0  0.15  0.15  0.45  0.11  0.14
# 2013.0  0.13  0.29  0.09  0.10  0.39
# 2014.0  0.29  0.13  0.10  0.35  0.12
# 2015.0  0.15  0.11  0.43  0.16  0.16
# 2016.0  0.10  0.36  0.14  0.14  0.25

# %%
fractIR = np.array([
["Irri",45.75, 50.94, 50.93, 51.40, 52.51, 53.22, 54.54, 51.04],
["Rain", 54.25, 49.06, 49.07, 48.60, 47.49, 46.78, 45.46, 48.96]])
dfractIR= pd.DataFrame(fractIR,columns=["system",2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])
dfractIR = dfractIR.set_index("system")
print("\nFractions of irrigated versus rainfeed area ")
print(dfractIR.head())

area = np.array([[0, 1500], [1, 79000], [2, 100], [3, 100], [4, 300], [5, 800], [6, 400], [7, 100], [8, 100], [9, 100], [10, 3600], [11, 400], [12, 21200], [13, 500], [14, 100], [15, 100], [16, 700], [17, 1400], [18, 900], [19, 800], [20, 100], [21, 200], [22, 400], [23, 100], [24, 900], [25, 100], [26, 100], [27, 100], [28, 100], [29, 700], [30, 400], [31, 300], [32, 1600], [33, 100], [34, 100], [35, 100], [36, 500], [37, 100], [38, 300], [39, 300], [40, 300], [41, 300], [42, 100], [43, 100], [44, 100], [45, 100], [46, 100], [47, 400], [48, 2100], [49, 300], [50, 200], [51, 200], [52, 500], [53, 100], [54, 100], [55, 100], [56, 300], [57, 100], [58, 5800], [59, 900], [60, 700], [61, 200], [62, 300], [63, 200], [64, 300], [65, 700], [66, 300], [67, 100], [68, 600], [69, 100], [70, 300], [71, 1300], [72, 100], [73, 400],
], [1463, 200], [1464, 100], [1465, 600], [1466, 2000], [1467, 100], [1468, 100], [1469, 500], [1470, 1300], [1471, 100], [1472, 600], [1473, 200], [1474, 1100], [1475, 300], [1476, 100], [1477, 100], [1478, 100], [1479, 300], [1480, 100], [1481, 400], [1482, 400], [1483, 2300], [1484, 42300], [1485, 400], [1486, 9600], [1487, 200], [1488, 100], [1489, 100], [1490, 100], [1491, 100], [1492, 100], [1493, 200], [1494, 500], [1495, 100], [1496, 500], [1497, 2000], [1498, 100], [1499, 200], [1500, 100], [1501, 100], [1502, 200], [1503, 100], [1504, 500], [1505, 300], [1506, 100], [1507, 100], [1508, 100], [1509, 13600], [1510, 100], [1511, 100], [1512, 200], [1513, 100], [1514, 100], [1515, 200], [1516, 7700], [1517, 100], [1518, 5500], [1519, 100], [1520, 100], [1521, 100], [1522, 200], [1523, 1500], [1524, 100], [1525, 700], [1526, 400]]
)
#print (area)

dfArea = pd.DataFrame(area,columns=["xx","Surface"]).set_index("xx")

dfArea["id1"]=dfArea.index.values + 100000
dfArea["id2"]=dfArea.index.values + 200000
dfArea["id3"]=dfArea.index.values + 300000
dfArea["id4"]=dfArea.index.values + 400000
dfArea["id5"]=dfArea.index.values + 500000


dfArea= dfArea.reset_index()
dfArea = dfArea.set_index("id1")
print("\nIndex system used, xx=GIS id, id1 = rot1 ids, id2 = rot2 ids ... \n")
print(dfArea.head())
# Out:
# Fractions of irrigated versus rainfeed area
#          2010   2011   2012  2013   2014   2015   2016   2017
# system
# Irri    45.75  50.94  50.93  51.4  52.51  53.22  54.54  51.04
# Rain    54.25  49.06  49.07  48.6  47.49  46.78  45.46  48.96
#
# Index system used, xx=GIS id, id1 = rot1 ids, id2 = rot2 ids ...
#
#         xx  Surface     id2     id3     id4     id5
# id1
# 100000   0     1500  200000  300000  400000  500000
# 100001   1    79000  200001  300001  400001  500001
# 100002   2      100  200002  300002  400002  500002
# 100003   3      100  200003  300003  400003  500003
# 100004   4      300  200004  300004  400004  500004

# %%
print ("Selecting the output variable for the result aggregation \n")
var = "aN_n2o_emis[kgNha-1]"
var = "aN_no3_leach[kgNha-1]"
# Out:
# Selecting the output variable for the result aggregation

# %%
print("\nReading in all the LDNDC output files for rain/irri & rot1 ... rot5 \n")
SCYrain1 = pd.read_csv("./GR_thessaly_dndc_rain_rot-1_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
SCYrain2 = pd.read_csv("./GR_thessaly_dndc_rain_rot-2_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
SCYrain3 = pd.read_csv("./GR_thessaly_dndc_rain_rot-3_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
SCYrain4 = pd.read_csv("./GR_thessaly_dndc_rain_rot-4_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
SCYrain5 = pd.read_csv("./GR_thessaly_dndc_rain_rot-5_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
SCYirri1 = pd.read_csv("./GR_thessaly_dndc_irri_rot-1_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
SCYirri2 = pd.read_csv("./GR_thessaly_dndc_irri_rot-2_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
SCYirri3 = pd.read_csv("./GR_thessaly_dndc_irri_rot-3_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
SCYirri4 = pd.read_csv("./GR_thessaly_dndc_irri_rot-4_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
SCYirri5 = pd.read_csv("./GR_thessaly_dndc_irri_rot-5_soilchemistry-yearly.txt", sep="\t", index_col=[2,1])
print("\nSome sample data \n")
print (SCYrain1[[var]].head())
# Out:
# Reading in all the LDNDC output files for rain/irri & rot1 ... rot5
#
#
# Some sample data
#
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 100000                2.15388
# 2010-12-31 00:00:00 100000               42.37530
# 2011-12-31 00:00:00 100000                4.45190
# 2012-12-31 00:00:00 100000                5.01796
# 2013-12-31 00:00:00 100000                1.74617

# %%
print("Scaling rotation 1 \n ==> multiplying the LDNDC result [kgNha-1] by the fraction of LU and the area of the polygon.")
print(" Resulting in the absolute contribution of the rotation 1 to the polygon (still neglecting rainfed / irrigation)")
scaledRrot1 = SCYrain1[[var]].copy()
scaledRrot1 = scaledRrot1 * 0
scaledIrot1 = SCYirri1[[var]].copy()
scaledIrot1 = scaledIrot1 * 0
for (t,i) in SCYrain1.index.values : 
    #print (t,i)
    year = t[:4]
    #print ( year) 
    if ( year == "2009"):
        continue
    #print(SCYrain1.loc[t,i][var])
    #print(dfract.loc[float(year)]["rot1"])
    #print(dfArea.loc[i]["Surface"])
    scaledRrot1.loc[t,i] = SCYrain1.loc[t,i][var] * dfract.loc[float(year)]["rot1"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Rain"][int(year)])/100.0
    scaledIrot1.loc[t,i] = SCYirri1.loc[t,i][var] * dfract.loc[float(year)]["rot1"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Irri"][int(year)])/100.0
#
print("\n Sample Result for rainfed rotation 1")
print(scaledRrot1.head())
# Out:
# Scaling rotation 1
#  ==> multiplying the LDNDC result [kgNha-1] by the fraction of LU and the area of the polygon.
#  Resulting in the absolute contribution of the rotation 1 to the polygon (still neglecting rainfed / irrigation)
#
#  Sample Result for rainfed rotation 1
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 100000               0.000000
# 2010-12-31 00:00:00 100000            2758.632030
# 2011-12-31 00:00:00 100000            1375.984348
# 2012-12-31 00:00:00 100000             554.020419
# 2013-12-31 00:00:00 100000             165.484531

# %%
scaledRrot2 = SCYrain2[[var]].copy()
scaledRrot2 = scaledRrot2 * 0
scaledIrot2 = SCYirri2[[var]].copy()
scaledIrot2 = scaledIrot2 * 0

dfArea = dfArea.reset_index()
dfArea = dfArea.set_index("id2")
for (t,i) in SCYrain2.index.values : 
    #print (t,i)
    year = t[:4]
    #print ( year) 
    if ( year == "2009"):
        continue
    scaledRrot2.loc[t,i] = SCYrain2.loc[t,i][var] * dfract.loc[float(year)]["rot2"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Rain"][int(year)])/100.0
    scaledIrot2.loc[t,i] = SCYirri2.loc[t,i][var] * dfract.loc[float(year)]["rot2"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Irri"][int(year)])/100.0
#
print(scaledRrot2.head())
# Out:
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 200000               0.000000
# 2010-12-31 00:00:00 200000            9794.600156
# 2011-12-31 00:00:00 200000             129.878991
# 2012-12-31 00:00:00 200000               0.000000
# 2013-12-31 00:00:00 200000            1281.952186

# %%
scaledRrot3 =    SCYrain3[[var]].copy()
scaledRrot3 = scaledRrot3 * 0
scaledIrot3 =    SCYirri3[[var]].copy()
scaledIrot3 = scaledIrot3 * 0

dfArea = dfArea.reset_index()
dfArea = dfArea.set_index("id3")
for (t,i) in SCYrain3.index.values : 
    #print (t,i)
    year = t[:4]
    #print ( year) 
    if ( year == "2009"):
        continue
    scaledRrot3.loc[t,i] = SCYrain3.loc[t,i][var] * dfract.loc[float(year)]["rot3"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Rain"][int(year)])/100.0
    scaledIrot3.loc[t,i] = SCYirri3.loc[t,i][var] * dfract.loc[float(year)]["rot3"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Irri"][int(year)])/100.0
#
print(scaledRrot3.head())


scaledRrot4 =    SCYrain4[[var]].copy()
scaledRrot4 = scaledRrot4 * 0
scaledIrot4 =    SCYirri4[[var]].copy()
scaledIrot4 = scaledIrot4 * 0
dfArea = dfArea.reset_index()
dfArea = dfArea.set_index("id4")
for (t,i) in SCYrain4.index.values : 
    #print (t,i)
    year = t[:4]
    #print ( year) 
    if ( year == "2009"):
        continue
    scaledRrot4.loc[t,i] = SCYrain4.loc[t,i][var] * dfract.loc[float(year)]["rot4"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Rain"][int(year)])/100.0
    scaledIrot4.loc[t,i] = SCYirri4.loc[t,i][var] * dfract.loc[float(year)]["rot4"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Irri"][int(year)])/100.0
#
print(scaledRrot4.head())

scaledRrot5 =    SCYrain5[[var]].copy()
scaledRrot5 = scaledRrot5 * 0
scaledIrot5 =    SCYirri5[[var]].copy()
scaledIrot5 = scaledIrot5 * 0

dfArea = dfArea.reset_index()
dfArea = dfArea.set_index("id5")
for (t,i) in SCYrain5.index.values : 
    #print (t,i)
    year = t[:4]
    #print ( year) 
    if ( year == "2009"):
        continue
    scaledRrot5.loc[t,i] = SCYrain5.loc[t,i][var] * dfract.loc[float(year)]["rot5"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Rain"][int(year)])/100.0
    scaledIrot5.loc[t,i] = SCYirri5.loc[t,i][var] * dfract.loc[float(year)]["rot5"] * dfArea.loc[i]["Surface"] * float(dfractIR.loc["Irri"][int(year)])/100.0
#
print(scaledRrot5.head())
print (dfArea.head() )
# Out:
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 300000               0.000000
# 2010-12-31 00:00:00 300000             181.582860
# 2011-12-31 00:00:00 300000               0.000000
# 2012-12-31 00:00:00 300000            5345.864906
# 2013-12-31 00:00:00 300000             225.256189
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 400000               0.000000
# 2010-12-31 00:00:00 400000             181.582860
# 2011-12-31 00:00:00 400000             449.301684
# 2012-12-31 00:00:00 400000             925.038934
# 2013-12-31 00:00:00 400000             997.417800
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 500000               0.000000
# 2010-12-31 00:00:00 500000            9684.549420
# 2011-12-31 00:00:00 500000             127.304077
# 2012-12-31 00:00:00 500000            1438.525815
# ...

# %%
print("\n Next step we sum up for all polygons the contributions of the 5 rotations. ")
print("The rainTotal contains the contribution of the rainfed management to the polygon")
print("")
print(scaledRrot1.head())

rainTotal = scaledRrot1.copy()
irriTotal = scaledIrot1.copy()

rainTotal[var]= scaledRrot1[var].values + scaledRrot2[var].values + scaledRrot3[var].values + scaledRrot4[var].values + scaledRrot5[var].values 
irriTotal[var]= scaledIrot1[var].values + scaledIrot2[var].values + scaledIrot3[var].values + scaledIrot4[var].values + scaledIrot5[var].values 

print (rainTotal.head(n=10))
print ( irriTotal.head(n=10))
# Out:
#  Next step we sum up for all polygons the contributions of the 5 rotations.
# The rainTotal contains the contribution of the rainfed management to the polygon
#
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 100000               0.000000
# 2010-12-31 00:00:00 100000            2758.632030
# 2011-12-31 00:00:00 100000            1375.984348
# 2012-12-31 00:00:00 100000             554.020419
# 2013-12-31 00:00:00 100000             165.484531
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 100000           0.000000e+00
# 2010-12-31 00:00:00 100000           2.260095e+04
# 2011-12-31 00:00:00 100000           2.082469e+03
# 2012-12-31 00:00:00 100000           8.263450e+03
# 2013-12-31 00:00:00 100000           3.761364e+03
# 2014-12-31 00:00:00 100000           4.296383e+03
# 2015-12-31 00:00:00 100000           2.173545e+03
# 2016-12-31 00:00:00 100000           2.715691e+03
# ...

# %%
#scaledRain = pd.DataFrame({"datetime":["2009-12-31 00:00:00"],"id":[0],var:[0.0]})
#scaledRain = scaledRain.set_index(["datetime","id"])
#scaledIrri = pd.DataFrame({"datetime":[],"id":[],var:[]})
#scaledIrri = scaledIrri.set_index(["datetime","id"])
#print(scaledRain.head())
#print(scaledIrri.head())
#print()

# %%
#for (t,i) in SCYrain1.index.values : 
#    j =  i - 100000
#    #print (t,j)
#    year = t[:4]
#    print (t, year, j) 
#    if ( year == "2009"):
#        continue
#    print(scaledRrot1.loc[t, j + 100000][var])
#    print(scaledRrot2.loc[t, j + 200000][var])
#    print(" scaledRain.loc[t, j] = ")
#    scaledRain.loc[t, j] = scaledRrot1.loc[t, j + 100000][var] + scaledRrot2.loc[t, j + 200000][var] + scaledRrot3.loc[t, j + 300000][var] + scaledRrot4.loc[t, j + 400000][var] + scaledRrot5.loc[t, j + 500000][var]  
#    scaledIrri.loc[t, j] = scaledIrot1.loc[t, j + 100000][var] + scaledIrot2.loc[t, j + 200000][var] + scaledIrot3.loc[t, j + 300000][var] + scaledIrot4.loc[t, j + 400000][var] + scaledIrot5.loc[t, j + 500000][var]  
#    print( scaledRain.loc[t, j] ) 
#    print(scaledRain.head(n=10))
#    print(scaledIrri.head(n=10))
#    break
#    #
#print(scaledRain.head(n=10))
#print(scaledIrri.head(n=10))

# %%
##y="2015"
##i = 100005
##print("scaledIrri ", scaledIrri.loc[y+"-12-31 00:00:00", i])
##print("scaledRain ", scaledRain.loc[y+"-12-31 00:00:00", i])
##print ()
##print (scaledIrri.index.values)
##print()
#for (t,i) in scaledIrri.index.values:
#    #print (t,i)
#    #for y in ["2009","2010", "2011", "2012", "2013","2014", "2015", "2016"]:
#    #print ("before update: " , scaledRain.loc[y+"-12-31 00:00:00", i])        
#    #print ("before update: " , scaledIrri.loc[y+"-12-31 00:00:00", i])        
#    scaledRain.loc[t, i] = scaledRain.loc[t, i] * dfArea.loc[i]["Surface"] 
#    scaledIrri.loc[t, i] = scaledIrri.loc[t, i] * dfArea.loc[i]["Surface"] 
#    #print ("nach update: " , scaledRain.loc[y+"-12-31 00:00:00", i] , scaledIrri.loc[y+"-12-31 00:00:00", i])
#    #
##
print("updated")
print (dfArea.head())
dfArea = dfArea.reset_index()
dfArea = dfArea.set_index("id1")
# Out:
# updated
#            id4     id3     id2     id1  xx  Surface
# id5
# 500000  400000  300000  200000  100000   0     1500
# 500001  400001  300001  200001  100001   1    79000
# 500002  400002  300002  200002  100002   2      100
# 500003  400003  300003  200003  100003   3      100
# 500004  400004  300004  200004  100004   4      300

# %%
print(dfractIR.head())
print(rainTotal.head())
print(irriTotal.head())

#total = pd.DataFrame( {'datetime': [], 'id': [], var : []})
total = rainTotal.copy()
total = total * 0
rate = rainTotal.copy()
rate = rate * 0

print(total.head())
print()
#total = total.set_index(["datetime","id"])

#print(total)
dfArea = dfArea.reset_index()
dfArea = dfArea.set_index("id1")
for (t,i) in irriTotal.index.values:
    #print (t,i)
    if (t[:4] == "2009"):
        continue
    #
    year = int(t[:4])
    #print(dfractIR.loc["Rain"][year])
    #print(dfractIR.loc["Irri"][year])
    
    #print(scaledRain.loc[t,i])
    #print(dfractIR.loc["Rain"][year])
    #print(scaledIrri.loc[t,i])
    #print(dfractIR.loc["Irri"][year])
    
    f1 = float(rainTotal.loc[t,i])
    f2 = 1
    f3 = float(irriTotal.loc[t,i])
    f4 = 1
    total.loc[t,i] = ( f1  + f3 )     
    rate.loc[t,i] = ( f1  + f3 )  / dfArea.loc[i]["Surface"]  
   #print (total.loc[t,i])
    #break
#
print (" total ", var )
print(total.head())
total.to_csv("total_"+var+".csv")
rate.to_csv("rate_"+var+".csv")
# Out:
#          2010   2011   2012  2013   2014   2015   2016   2017
# system
# Irri    45.75  50.94  50.93  51.4  52.51  53.22  54.54  51.04
# Rain    54.25  49.06  49.07  48.6  47.49  46.78  45.46  48.96
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 100000               0.000000
# 2010-12-31 00:00:00 100000           22600.947327
# 2011-12-31 00:00:00 100000            2082.469101
# 2012-12-31 00:00:00 100000            8263.450074
# 2013-12-31 00:00:00 100000            3761.363563
#                             aN_no3_leach[kgNha-1]
# datetime            id
# 2009-12-31 00:00:00 100000               0.000000
# 2010-12-31 00:00:00 100000           27032.962169
# 2011-12-31 00:00:00 100000            8303.095806
# 2012-12-31 00:00:00 100000           13127.563399
# 2013-12-31 00:00:00 100000            6709.932392
#                             aN_no3_leach[kgNha-1]
# datetime            id
# ...

# %%
time = []
values = []
q5 = []
q10 = []
q25 = []
median = []
q75 = []
q90 = []
q95 = []
for t in range(2011,2017):
    dt = "%s-12-31 00:00:00" % t
    
    print(dt)
    time.append(t) 
    values.append( float(total.loc[(dt,)].sum().values[0]))
    q5.append( float(rate.loc[(dt,)].quantile(0.02).values[0]))
    q10.append( float(rate.loc[(dt,)].quantile(0.1).values[0]))
    q25.append( float(rate.loc[(dt,)].quantile(0.25).values[0]))
    q90.append( float(rate.loc[(dt,)].quantile(0.9).values[0]))
    q95.append( float(rate.loc[(dt,)].quantile(0.98).values[0]))
    q75.append( float(rate.loc[(dt,)].quantile(0.75).values[0]))
    median.append( float(rate.loc[(dt,)].median().values[0]))
#
print(time)
print(values)
print(median)
# Out:
# 2011-12-31 00:00:00
# 2012-12-31 00:00:00
# 2013-12-31 00:00:00
# 2014-12-31 00:00:00
# 2015-12-31 00:00:00
# 2016-12-31 00:00:00
# [2011, 2012, 2013, 2014, 2015, 2016]
# [18090791.938797418, 20579477.89057906, 13646113.730521277, 10355754.733782731, 12404985.442279795, 11261035.567481011]
# [15.165764999020002, 18.792004137430002, 12.547554298599998, 8.516612844139999, 9.497165448616, 9.628499745760001]
# /Users/haas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: PerformanceWarning: indexing past lexsort depth may impact performance.
#   from ipykernel import kernelapp as app
# /Users/haas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: PerformanceWarning: indexing past lexsort depth may impact performance.
#   app.launch_new_instance()
# /Users/haas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: PerformanceWarning: indexing past lexsort depth may impact performance.
# ...

# %%
plt.plot(time, values)

# %%
plt.plot(time, median, color="black" )
plt.plot(time, q5, color="green")
plt.plot(time, q95, color="green")
plt.plot(time, q10, color="blue")
plt.plot(time, q90, color="blue")
plt.plot(time, q25, color="red")
plt.plot(time, q75, color="red")
plt.fill_between(time,q5,q95,color="green", alpha=0.25)
plt.fill_between(time,q10,q90,color="blue", alpha=0.25)
plt.fill_between(time,q25,q75,color="red", alpha=0.25)
